# %%
#一般class 後面第一個字母都大寫
class Person:
    def __init__(self,name:str,age:int):
     self.name = name
     self.age = age

# %%
p1 = Person("Robert",32)
print(p1.name)
print(p1.age)
# Out:
# Robert
# 32

# %%
p2 = Person(age=35,name = "Alice")
print(p2.name)
print(p2.age)
# Out:
# Alice
# 35
