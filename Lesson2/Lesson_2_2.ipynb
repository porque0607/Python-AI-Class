# %%
#矩形面積
width = 58.77
height = 37.888
area = width * height
print(area)
# Out:
# 2226.67776

# %%
print ("累累der~~我的老腰啊啊啊啊啊~~~")
# Out:
# 累累der~~我的老腰啊啊啊啊啊~~~

# %%
print("feel tired")
# Out:
# feel tired

# %%
# 整數
5
# Out:
# 5
