# %%
#全部都在root區,所以每個敘述都要靠左

# %%
age = 17

if age >= 18:
    print("我滿18歲")
    print("可以考駕照")

else:
    print("未滿法定年齡")
    print("不可以考駕照")
# Out:
# 未滿法定年齡
# 不可以考駕照

# %%
age = int(input("請輸入年齡"))

if age >= 18:
    print("我滿18歲")
    print("可以考駕照")

else:
    print("未滿法定年齡")
    print("不可以考駕照")
# Out:
# 我滿18歲
# 可以考駕照
