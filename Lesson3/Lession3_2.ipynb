# %%
#這是次標題
###這是次次標題

-這是項目符號
-這是項目符號

-這是項目編號
-

# %%
#字串可以使用的數學運算子
print("我的姓名:"+"report")
print("=" * 50)
# Out:
# 我的姓名:report
# ...

# %%
#字串的特別符號
# \n >換行
# \t >tab

"我的個人資料:\n姓名:\t陳宜敏\n性別:\t女"
# Out:
# '我的個人資料:\n姓名:\t陳宜敏\n性別:\t女'

# %%
#字串的特別符號
# \n >換行
# \t >tab

print("我的個人資料:\n姓名:\t陳宜敏\n性別:\t女")
# Out:
# 我的個人資料:
# 姓名:	陳宜敏
# 性別:	女

# %%
#多行文字
info = '''我的個人資料:
姓名:陳宜敏
性別:女'''

print(info)
# Out:
# 我的個人資料:
# 姓名:陳宜敏
# 性別:女

# %%
#字串和變數的整合
#格式化字串(字串插補)

fruits = 10
apple = 7
banana = 3

result = f"我有水果:{fruits}個,蘋果:{apple}顆,香蕉:{banana}條"

print(result)
# Out:
# 我有水果:10個,蘋果:7顆,香蕉:3條
